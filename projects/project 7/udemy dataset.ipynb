# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('udemy.csv')

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data.groupby('subject')['course_title'].count().sort_values()
# Out:
# subject
# Graphic Design          603
# Musical Instruments     680
# Business Finance       1199
# Web Development        1200
# Name: course_title, dtype: int64

# %%
data.groupby('subject')['course_title'].value_counts()
# Out:
# subject           course_title
# Business Finance  CFA Level 2- Quantitative Methods                           2
#                   Essentials of money value: Get a financial Life !           2
#                   Introduction to Forex Trading Business For Beginners        2
#                   Understanding Financial Statements                          2
#                   'Geometry Of Chance strategy of defeating the roulette."    1
#                                                                              ..
# Web Development   jQuery UI in Action: Build 5 jQuery UI Projects             1
#                   jQuery for Absolute Beginners - Lite                        1
#                   jQuery for Beginners                                        1
#                   jQuery for Beginners - Create Website Animations Easily     1
#                   jQuery in Action: Build 8 jQuery Projects                   1
# Name: course_title, Length: 3667, dtype: int64

# %%
data[data['is_paid']==True].count()
# Out:
# course_id              3372
# course_title           3372
# is_paid                3372
# price                  3372
# num_subscribers        3372
# num_reviews            3372
# num_lectures           3372
# level                  3372
# content_duration       3372
# published_timestamp    3372
# subject                3372
# dtype: int64

# %%
data[data['is_paid']==False].count()
# Out:
# course_id              310
# course_title           310
# is_paid                310
# price                  310
# num_subscribers        310
# num_reviews            310
# num_lectures           310
# level                  310
# content_duration       310
# published_timestamp    310
# subject                310
# dtype: int64

# %%
data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=False).index[0]
# Out:
# 'Learn HTML5 Programming From Scratch'

# %%
len(data['course_title'].unique())
# Out:
# 3667

# %%
data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=True).index[0]
# Out:
# 'Learn to trade using technical analysis'

# %%
data.sort_values('num_subscribers',ascending=False).head()
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 2230  Free           268923         8629            45      All Levels
# 776   Free           161029          279            27  Beginner Level
# 3385   200           121584        27445           342      All Levels
# 640   Free           120291         5924            30  Beginner Level
# 3316   200           114512        22412           304      All Levels
#
#      content_duration   published_timestamp          subject
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
data['price'].replace('Free',np.nan,inplace=True)

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3372 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
data['price'].unique()
# Out:
# array(['35', '75', '65', '200', '25', '100', '20', '40', '30', '45',
#        '185', '120', '105', '50', nan, '145', '55', '85', '110', '150',
#        '95', '180', '125', '60', '90', '195', '80', '70', '140', '190',
#        '115', '130', '170', '175', '165', '135', '155', '160'],
#       dtype=object)

# %%
# to_numeric() - provides functionality to safely convert non-numeric types (e.g. strings) to a suitable numeric type. (See also to_datetime() and to_timedelta().)

# astype() - convert (almost) any type to (almost) any other type (even if it's not necessarily sensible to do so). Also allows you to convert to categorial types (very useful).

# infer_objects() - a utility method to convert object columns holding Python objects to a pandas type if possible.

# convert_dtypes() - convert DataFrame columns to the "best possible" dtype that supports pd.NA (pandas' object to indicate a missing value).

# %%
data['price']=data['price'].apply(pd.to_numeric)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3372 non-null   float64
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), float64(1), int64(4), object(5)
# memory usage: 291.4+ KB

# %%
k.groupby('subject').get_group('Graphic Design')
# Out:
#       course_id                                       course_title  is_paid  \
# 63       413713  A Complete Guide to Successful Freelance Logo ...     True
# 87      1139792                                           会声会影深度教学     True
# 157     1013676            Adobe Illustrator CC 2017 for beginners     True
# 166      905244  Adobe Illustrator For Everyone: Create Detaile...     True
# 171      933888  Adobe Illustrator: How to Draw Squared Animals...     True
# ...         ...                                                ...      ...
# 3482     635716       Typography: Learn the Foundation and Designs     True
# 3483     948294            مدخل في أساسيات الفوطوشوب للمبتدئين فقط     True
# 3499     438420  Ultimate Guide on Freelancing Career in Photos...     True
# 3505    1046722  Ultimate Photoshop Training: From Beginner to Pro     True
# 3533    1067516            Vector Logo Design in Affinity Designer     True
#
# ...

# %%
k=data[data['price']>100]

# %%
k
# Out:
#       course_id                                       course_title  is_paid  \
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 9        738910  [Value Investing] Where White People Keep Thei...     True
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# ...         ...                                                ...      ...
# 3637     361620                              Wordpress Tutorial        True
# 3640     774910     WordPress: Create an Amazing Website With Ease     True
# 3649    1229274     WP Plugin Development - Build your own plugin!     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
#
# ...

# %%
q=data['course_title'].str.lower()

# %%
q.str.contains('python').value_counts()
# Out:
# False    3653
# True       29
# Name: course_title, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3372 non-null   float64
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), float64(1), int64(4), object(5)
# memory usage: 291.4+ KB

# %%
data['course_title']=data['course_title'].str.lower()

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 piano hand coordination: play 10th ballad i...     True
# 1    1170074  #10 hand coordination - transfer chord ballad ...     True
# 2    1193886  #12 hand coordination: let your hands dance wi...     True
# 3    1116700  #4 piano hand coordination: fun piano runs in ...     True
# 4    1120410  #5  piano hand coordination:  piano runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0   35.0             3137           18            68          All Levels
# 1   75.0             1593            1            41  Intermediate Level
# 2   75.0              482            1            47  Intermediate Level
# 3   75.0              850            3            43  Intermediate Level
# 4   75.0              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data['published_timestamp']=pd.to_datetime(data['published_timestamp'])

# %%
data[data['published_timestamp'].dt.year==2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - concepts of statistics for beginners step ...     True
# 16       302450        10 numbers every business owner should know     True
# 19       384928  101 blues riffs - learn how the harmonica supe...     True
# 23       550842  16 guitar chords to jam with - (beginner - int...     True
# 26       486240      2 easy steps to investment and avoiding traps     True
# ...         ...                                                ...      ...
# 3675     551170                         your first course on piano     True
# 3676     498488  your first successful forex trades - with case...     True
# 3677     328960  your own site in 45 min: the complete wordpres...     True
# 3678     552700    your second course on piano: two handed playing     True
# 3679     631754  zend framework 2: learn the php framework zf2 ...     True
#
# ...

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max()
# Out:
#                     course_id                                  course_title  \
# level
# All Levels            1277924                 ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level        1282064    ７日でマスター  ビギナー向け adobe illustrator　どきどきセミナー
# Expert Level          1275790  working capital management for entrepreneurs
# Intermediate Level    1276182                      株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# All Levels             True  200.0           268923        27445
# Beginner Level         True  200.0           161029         5924
# Expert Level           True  200.0             5172          249
# Intermediate Level     True  200.0            29167         3326
#
#                     num_lectures content_duration       published_timestamp  \
# level
# All Levels                   544        9.5 hours 2017-07-06 21:16:13+00:00
# Beginner Level               779        9.5 hours 2017-07-06 21:46:30+00:00
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                              float64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object
